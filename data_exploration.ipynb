# %%
import string
from PIL import Image
import os
import numpy as np
import hashlib
import shutil
import sys
#sys.path.append('../')
from validate import validate_images
import os
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /home/massive_rabbit/Documents/ex5/data_exploration.ipynb Cell 1' in <cell line: 9>()
#       <a href='vscode-notebook-cell:/home/massive_rabbit/Documents/ex5/data_exploration.ipynb#ch0000000?line=6'>7</a> import sys
#       <a href='vscode-notebook-cell:/home/massive_rabbit/Documents/ex5/data_exploration.ipynb#ch0000000?line=7'>8</a> #sys.path.append('../')
# ----> <a href='vscode-notebook-cell:/home/massive_rabbit/Documents/ex5/data_exploration.ipynb#ch0000000?line=8'>9</a> from validate import validate_images
#      <a href='vscode-notebook-cell:/home/massive_rabbit/Documents/ex5/data_exploration.ipynb#ch0000000?line=9'>10</a> import os
#
# ImportError: cannot import name 'validate_images' from 'validate' (/home/massive_rabbit/Documents/ex5/validate.py)

# %%
input_dir = os.path.abspath(r"/Ex5/training")
output_dir = os.path.abspath(r"/Ex5/Data/Valid_training")
logfile = os.path.abspath(r"/Ex5/Data/logfile.log")
formatter = "06d"

print(utils.validate.validate_images(input_dir, output_dir, logfile, formatter))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/massive_rabbit/Documents/ex5/data_exploration.ipynb Cell 2' in <cell line: 6>()
#       <a href='vscode-notebook-cell:/home/massive_rabbit/Documents/ex5/data_exploration.ipynb#ch0000001?line=2'>3</a> logfile = os.path.abspath(r"/Ex5/Data/logfile.log")
#       <a href='vscode-notebook-cell:/home/massive_rabbit/Documents/ex5/data_exploration.ipynb#ch0000001?line=3'>4</a> formatter = "06d"
# ----> <a href='vscode-notebook-cell:/home/massive_rabbit/Documents/ex5/data_exploration.ipynb#ch0000001?line=5'>6</a> print(utils.validate.validate_images(input_dir, output_dir, logfile, formatter))
#
# AttributeError: module 'utils.validate' has no attribute 'validate_images'
